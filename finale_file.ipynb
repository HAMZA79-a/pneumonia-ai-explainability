# %% [markdown]
# # DenseNet121 Amélioré — Chest X-Ray (NORMAL vs PNEUMONIA)
#
# ## Améliorations par rapport à la version précédente :
# - ✅ **Bug normalisation corrigé** : utilisation de `preprocess_input` de DenseNet
# - ✅ **Fine-tuning en 2 phases** : tête d'abord, puis backbone progressivement
# - ✅ **val_dataset normalisé** avant évaluation
# - ✅ **Monitoring sur val_auc** (plus robuste que val_loss avec déséquilibre)
# - ✅ **Recherche du seuil optimal** pour maximiser F1 NORMAL
# - ✅ **BatchNormalization + Dense(256)** dans la tête de classification

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Chemins

# %%
dataset_path = r"C:\Users\HP\Documents\IA\Stage\data\chest_xray\chest_xray"

# %% [markdown]
# ## 2. Chargement des datasets

# %%
IMG_SIZE   = (224, 224)
BATCH_SIZE = 32
SEED       = 42

train_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(dataset_path, "train"),
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(dataset_path, "train"),
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(dataset_path, "test"),
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 5216 files belonging to 2 classes.
# Using 4173 files for training.
# Found 5216 files belonging to 2 classes.
# Using 1043 files for validation.
# Found 624 files belonging to 2 classes.

# %%
classes = ['NORMAL', 'PNEUMONIA']

for folder in ['train','val','test']:

    print(f"\n------ {folder} ------")

    for c in classes:

        path = os.path.join(dataset_path,folder,c)

        n = len(os.listdir(path))

        print(c,":",n)
# Out:
# ------ train ------
# NORMAL : 1342
# PNEUMONIA : 3876
#
# ------ val ------
# NORMAL : 9
# PNEUMONIA : 9
#
# ------ test ------
# NORMAL : 234
# PNEUMONIA : 390

# %%
total = 0

for folder in ['train', 'val', 'test']:

    for c in classes:

        path = os.path.join(dataset_path, folder, c)

        total += len(os.listdir(path))

print("Nombre total d'images :", total)
# Out:
# Nombre total d'images : 5860

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

train_normal = r"C:\Users\HP\Documents\IA\Stage\data\chest_xray\chest_xray\train\NORMAL"

# Garder uniquement les fichiers images
image_files = [
    f for f in os.listdir(train_normal)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

# Choisir une image
image_name = image_files[0]

# Construire le chemin
image_path = os.path.join(train_normal, image_name)

# Ouvrir l'image
image = Image.open(image_path)

# Afficher
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.title("Image NORMAL")
plt.show()

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

train_normal = r"C:\Users\HP\Documents\IA\Stage\data\chest_xray\chest_xray\train\PNEUMONIA"

# Garder uniquement les fichiers images
image_files = [
    f for f in os.listdir(train_normal)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

# Choisir une image
image_name = image_files[0]

# Construire le chemin
image_path = os.path.join(train_normal, image_name)

# Ouvrir l'image
image = Image.open(image_path)

# Afficher
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.title("Image Anormale")
plt.show()

# %% [markdown]
# ## 3. Normalisation — CORRECTION DU BUG
#
# > DenseNet121 a sa propre normalisation interne (`preprocess_input`).
# > Utiliser `Rescaling(1./255)` comme avant était **incorrect** pour ce backbone.

# %%
def preprocess(image, label):
    image = tf.cast(image, tf.float32)#Cette ligne convertit les pixels de l'image en nombres de type float32.
    image = preprocess_input(image)  # normalisation correcte pour DenseNet121
    return image, label

# %% [markdown]
# ## 4. Data Augmentation + Pipelines

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.05, 0.05),
    layers.RandomContrast(0.1),   # utile pour les radios
], name="data_augmentation")

def augment_and_preprocess(image, label):
    image = data_augmentation(image, training=True)
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    return image, label

# Pipelines optimisés
augmented_train = (
    train_dataset
    .map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(500)
    .prefetch(tf.data.AUTOTUNE)
)

normalized_val = (
    val_dataset
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

normalized_test = (
    test_dataset
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ## 5. Class Weights (gérer le déséquilibre NORMAL vs PNEUMONIA)

# %%
train_labels = np.concatenate([y.numpy() for x, y in train_dataset])

class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_labels),
    y=train_labels
)
class_weights = {i: w for i, w in enumerate(class_weights_array)}
print("Class weights:", class_weights)
# → {0: ~1.91 (NORMAL est sous-représenté), 1: ~0.68 (PNEUMONIA)}
# Out:
# Class weights: {0: np.float64(1.9107142857142858), 1: np.float64(0.6772151898734177)}

# %% [markdown]
#                     ┌──────────────────┐
# Image 224×224×3 ───→│   DenseNet121    │
#                     │     frozen       │
#                     └────────┬─────────┘
#                              ↓
#                   GlobalAveragePooling2D
#                              ↓
#                     BatchNormalization
#                              ↓
#                        Dense 256
#                         + ReLU
#                              ↓
#                        Dropout 40%
#                              ↓
#                       Dense 1 + Sigmoid
#                              ↓
#                     NORMAL / PNEUMONIA

# %% [markdown]
# ## 6. Construction du modèle
#
# Tête améliorée : `GlobalAveragePooling → BatchNorm → Dense(256) → Dropout(0.4) → Dense(1)`

# %%
base_model = DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # gelé pour la Phase 1
print(f"Backbone : {base_model.count_params():,} paramètres (gelés)")

inputs = tf.keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)        # ajouté pour stabiliser
x = layers.Dense(256, activation="relu")(x)  # couche plus riche
x = layers.Dropout(0.4)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = models.Model(inputs, outputs)
model.summary()
# Out:
# Backbone : 7,037,504 paramètres (gelés)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,304,257 (27.86 MB)
#  Trainable params: 264,705 (1.01 MB)
#  Non-trainable params: 7,039,552 (26.85 MB)

# %% [markdown]
# ## 7. Fonction de compilation

# %%
def compile_model(lr):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[
            tf.keras.metrics.BinaryAccuracy(name="accuracy"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )

compile_model(lr=1e-4)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## 8–9. Phase 1 : Entraîner uniquement la tête (backbone gelé)
#
# > Objectif : que la tête apprenne les features de base avant le fine-tuning

# %%
callbacks_phase1 = [
    EarlyStopping(
        monitor="val_auc", patience=5,
        restore_best_weights=True, mode="max", verbose=1
    ),
    ModelCheckpoint(
        "best_densenet121_phase1.keras",
        monitor="val_auc", save_best_only=True, mode="max", verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss", factor=0.3,
        patience=3, min_lr=1e-7, verbose=1
    ),
]

print("========== PHASE 1 : Entraînement de la tête ==========")
history1 = model.fit(
    augmented_train,
    validation_data=normalized_val,   # ← val normalisé (corrigé)
    epochs=15,
    class_weight=class_weights,
    callbacks=callbacks_phase1
)
# Out:
# ========== PHASE 1 : Entraînement de la tête ==========
# Epoch 1/15
# c:\Users\HP\Documents\IA\ANN\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8081 - auc: 0.9335 - loss: 0.3543 - precision: 0.9676 - recall: 0.7657
# Epoch 1: val_auc improved from None to 0.97642, saving model to best_densenet121_phase1.keras
#
# Epoch 1: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 550s 4s/step - accuracy: 0.8081 - auc: 0.9335 - loss: 0.3543 - precision: 0.9676 - recall: 0.7657 - val_accuracy: 0.9147 - val_auc: 0.9764 - val_loss: 0.2529 - val_precision: 0.9796 - val_recall: 0.9068 - learning_rate: 1.0000e-04
# Epoch 2/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9133 - auc: 0.9760 - loss: 0.2038 - precision: 0.9795 - recall: 0.9013
# Epoch 2: val_auc improved from 0.97642 to 0.98503, saving model to best_densenet121_phase1.keras
#
# Epoch 2: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 569s 4s/step - accuracy: 0.9133 - auc: 0.9760 - loss: 0.2038 - precision: 0.9795 - recall: 0.9013 - val_accuracy: 0.9281 - val_auc: 0.9850 - val_loss: 0.1908 - val_precision: 0.9878 - val_recall: 0.9169 - learning_rate: 1.0000e-04
# Epoch 3/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9343 - auc: 0.9848 - loss: 0.1627 - precision: 0.9805 - recall: 0.9296
# Epoch 3: val_auc improved from 0.98503 to 0.98678, saving model to best_densenet121_phase1.keras
#
# Epoch 3: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 740s 5s/step - accuracy: 0.9343 - auc: 0.9848 - loss: 0.1627 - precision: 0.9805 - recall: 0.9296 - val_accuracy: 0.9358 - val_auc: 0.9868 - val_loss: 0.1599 - val_precision: 0.9840 - val_recall: 0.9307 - learning_rate: 1.0000e-04
# Epoch 4/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.9418 - auc: 0.9876 - loss: 0.1442 - precision: 0.9830 - recall: 0.9374
# Epoch 4: val_auc improved from 0.98678 to 0.98869, saving model to best_densenet121_phase1.keras
#
# Epoch 4: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 3021s 23s/step - accuracy: 0.9418 - auc: 0.9876 - loss: 0.1442 - precision: 0.9830 - recall: 0.9374 - val_accuracy: 0.9291 - val_auc: 0.9887 - val_loss: 0.1748 - val_precision: 0.9918 - val_recall: 0.9144 - learning_rate: 1.0000e-04
# Epoch 5/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 1230s/step - accuracy: 0.9451 - auc: 0.9900 - loss: 0.1284 - precision: 0.9840 - recall: 0.9409
# Epoch 5: val_auc improved from 0.98869 to 0.99027, saving model to best_densenet121_phase1.keras
#
# Epoch 5: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 160006s 1231s/step - accuracy: 0.9451 - auc: 0.9900 - loss: 0.1284 - precision: 0.9840 - recall: 0.9409 - val_accuracy: 0.9262 - val_auc: 0.9903 - val_loss: 0.1764 - val_precision: 0.9931 - val_recall: 0.9093 - learning_rate: 1.0000e-04
# Epoch 6/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9511 - auc: 0.9909 - loss: 0.1223 - precision: 0.9871 - recall: 0.9461
# Epoch 6: val_auc improved from 0.99027 to 0.99114, saving model to best_densenet121_phase1.keras
#
# Epoch 6: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 17711s 136s/step - accuracy: 0.9511 - auc: 0.9909 - loss: 0.1223 - precision: 0.9871 - recall: 0.9461 - val_accuracy: 0.9386 - val_auc: 0.9911 - val_loss: 0.1556 - val_precision: 0.9906 - val_recall: 0.9282 - learning_rate: 1.0000e-04
# Epoch 7/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9490 - auc: 0.9897 - loss: 0.1256 - precision: 0.9838 - recall: 0.9464
# Epoch 7: val_auc improved from 0.99114 to 0.99184, saving model to best_densenet121_phase1.keras
#
# Epoch 7: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 644s 5s/step - accuracy: 0.9490 - auc: 0.9897 - loss: 0.1256 - precision: 0.9838 - recall: 0.9464 - val_accuracy: 0.9291 - val_auc: 0.9918 - val_loss: 0.1712 - val_precision: 0.9932 - val_recall: 0.9131 - learning_rate: 1.0000e-04
# Epoch 8/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9571 - auc: 0.9912 - loss: 0.1158 - precision: 0.9879 - recall: 0.9536
# Epoch 8: val_auc improved from 0.99184 to 0.99259, saving model to best_densenet121_phase1.keras
#
# Epoch 8: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 655s 5s/step - accuracy: 0.9571 - auc: 0.9912 - loss: 0.1158 - precision: 0.9879 - recall: 0.9536 - val_accuracy: 0.9310 - val_auc: 0.9926 - val_loss: 0.1642 - val_precision: 0.9932 - val_recall: 0.9156 - learning_rate: 1.0000e-04
# Epoch 9/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9566 - auc: 0.9926 - loss: 0.1083 - precision: 0.9866 - recall: 0.9542
# Epoch 9: val_auc improved from 0.99259 to 0.99298, saving model to best_densenet121_phase1.keras
#
# Epoch 9: finished saving model to best_densenet121_phase1.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 622s 4s/step - accuracy: 0.9566 - auc: 0.9926 - loss: 0.1083 - precision: 0.9866 - recall: 0.9542 - val_accuracy: 0.9338 - val_auc: 0.9930 - val_loss: 0.1704 - val_precision: 0.9932 - val_recall: 0.9194 - learning_rate: 1.0000e-04
# Epoch 10/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9602 - auc: 0.9929 - loss: 0.1047 - precision: 0.9850 - recall: 0.9607
# Epoch 10: val_auc improved from 0.99298 to 0.99308, saving model to best_densenet121_phase1.keras
#
# Epoch 10: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 636s 5s/step - accuracy: 0.9602 - auc: 0.9929 - loss: 0.1047 - precision: 0.9850 - recall: 0.9607 - val_accuracy: 0.9281 - val_auc: 0.9931 - val_loss: 0.1774 - val_precision: 0.9931 - val_recall: 0.9118 - learning_rate: 3.0000e-05
# Epoch 11/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9602 - auc: 0.9941 - loss: 0.0976 - precision: 0.9916 - recall: 0.9542
# Epoch 11: val_auc improved from 0.99308 to 0.99320, saving model to best_densenet121_phase1.keras
#
# Epoch 11: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 694s 5s/step - accuracy: 0.9602 - auc: 0.9941 - loss: 0.0976 - precision: 0.9916 - recall: 0.9542 - val_accuracy: 0.9271 - val_auc: 0.9932 - val_loss: 0.1776 - val_precision: 0.9931 - val_recall: 0.9106 - learning_rate: 3.0000e-05
# Epoch 12/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9564 - auc: 0.9933 - loss: 0.1043 - precision: 0.9882 - recall: 0.9523
# Epoch 12: val_auc improved from 0.99320 to 0.99339, saving model to best_densenet121_phase1.keras
#
# Epoch 12: finished saving model to best_densenet121_phase1.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 651s 5s/step - accuracy: 0.9564 - auc: 0.9933 - loss: 0.1043 - precision: 0.9882 - recall: 0.9523 - val_accuracy: 0.9300 - val_auc: 0.9934 - val_loss: 0.1743 - val_precision: 0.9932 - val_recall: 0.9144 - learning_rate: 3.0000e-05
# Epoch 13/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 484s/step - accuracy: 0.9590 - auc: 0.9935 - loss: 0.0994 - precision: 0.9889 - recall: 0.9552
# Epoch 13: val_auc improved from 0.99339 to 0.99348, saving model to best_densenet121_phase1.keras
#
# Epoch 13: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 63072s 485s/step - accuracy: 0.9590 - auc: 0.9935 - loss: 0.0994 - precision: 0.9889 - recall: 0.9552 - val_accuracy: 0.9300 - val_auc: 0.9935 - val_loss: 0.1750 - val_precision: 0.9932 - val_recall: 0.9144 - learning_rate: 9.0000e-06
# Epoch 14/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9557 - auc: 0.9922 - loss: 0.1104 - precision: 0.9853 - recall: 0.9542
# Epoch 14: val_auc improved from 0.99348 to 0.99349, saving model to best_densenet121_phase1.keras
#
# Epoch 14: finished saving model to best_densenet121_phase1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 578s 4s/step - accuracy: 0.9557 - auc: 0.9922 - loss: 0.1104 - precision: 0.9853 - recall: 0.9542 - val_accuracy: 0.9338 - val_auc: 0.9935 - val_loss: 0.1683 - val_precision: 0.9932 - val_recall: 0.9194 - learning_rate: 9.0000e-06
# Epoch 15/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9576 - auc: 0.9936 - loss: 0.0997 - precision: 0.9902 - recall: 0.9520
# Epoch 15: val_auc improved from 0.99349 to 0.99356, saving model to best_densenet121_phase1.keras
#
# Epoch 15: finished saving model to best_densenet121_phase1.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 534s 4s/step - accuracy: 0.9576 - auc: 0.9936 - loss: 0.0997 - precision: 0.9902 - recall: 0.9520 - val_accuracy: 0.9310 - val_auc: 0.9936 - val_loss: 0.1694 - val_precision: 0.9932 - val_recall: 0.9156 - learning_rate: 9.0000e-06
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# Le learning rate (taux d'apprentissage) détermine la taille des modifications apportées aux poids du modèle à chaque étape d'apprentissage.

# %% [markdown]
# ## 10. Phase 2 : Fine-tuning des 50 dernières couches du backbone
#
# > LR beaucoup plus faible (`1e-5`) pour ne pas détruire les poids ImageNet

# %%
base_model.trainable = True

# Geler tout SAUF les 50 dernières couches
for layer in base_model.layers[:-50]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f"Couches dégelées : {trainable_count} / {len(base_model.layers)}")

compile_model(lr=1e-5)  # LR 10x plus petit qu'en phase 1

callbacks_phase2 = [
    EarlyStopping(
        monitor="val_auc", patience=7,
        restore_best_weights=True, mode="max", verbose=1
    ),
    ModelCheckpoint(
        "best_densenet121_phase2.keras",
        monitor="val_auc", save_best_only=True, mode="max", verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss", factor=0.3,
        patience=3, min_lr=1e-8, verbose=1
    ),
]

print("========== PHASE 2 : Fine-tuning ==========")
history2 = model.fit(
    augmented_train,
    validation_data=normalized_val,
    epochs=20,
    class_weight=class_weights,
    callbacks=callbacks_phase2
)
# Out:
# Couches dégelées : 50 / 427
# ========== PHASE 2 : Fine-tuning ==========
# Epoch 1/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9573 - auc: 0.9923 - loss: 0.1100 - precision: 0.9869 - recall: 0.9549
# Epoch 1: val_auc improved from None to 0.99273, saving model to best_densenet121_phase2.keras
#
# Epoch 1: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 572s 4s/step - accuracy: 0.9573 - auc: 0.9923 - loss: 0.1100 - precision: 0.9869 - recall: 0.9549 - val_accuracy: 0.9453 - val_auc: 0.9927 - val_loss: 0.1427 - val_precision: 0.9920 - val_recall: 0.9358 - learning_rate: 1.0000e-05
# Epoch 2/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9549 - auc: 0.9928 - loss: 0.1069 - precision: 0.9865 - recall: 0.9520
# Epoch 2: val_auc improved from 0.99273 to 0.99273, saving model to best_densenet121_phase2.keras
#
# Epoch 2: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 532s 4s/step - accuracy: 0.9549 - auc: 0.9928 - loss: 0.1069 - precision: 0.9865 - recall: 0.9520 - val_accuracy: 0.9406 - val_auc: 0.9927 - val_loss: 0.1569 - val_precision: 0.9946 - val_recall: 0.9270 - learning_rate: 1.0000e-05
# Epoch 3/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9576 - auc: 0.9936 - loss: 0.1016 - precision: 0.9882 - recall: 0.9539
# Epoch 3: val_auc improved from 0.99273 to 0.99351, saving model to best_densenet121_phase2.keras
#
# Epoch 3: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 612s 4s/step - accuracy: 0.9576 - auc: 0.9936 - loss: 0.1016 - precision: 0.9882 - recall: 0.9539 - val_accuracy: 0.9453 - val_auc: 0.9935 - val_loss: 0.1459 - val_precision: 0.9946 - val_recall: 0.9332 - learning_rate: 1.0000e-05
# Epoch 4/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9561 - auc: 0.9927 - loss: 0.1058 - precision: 0.9876 - recall: 0.9526
# Epoch 4: val_auc improved from 0.99351 to 0.99387, saving model to best_densenet121_phase2.keras
#
# Epoch 4: finished saving model to best_densenet121_phase2.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 574s 4s/step - accuracy: 0.9561 - auc: 0.9927 - loss: 0.1058 - precision: 0.9876 - recall: 0.9526 - val_accuracy: 0.9444 - val_auc: 0.9939 - val_loss: 0.1442 - val_precision: 0.9946 - val_recall: 0.9320 - learning_rate: 1.0000e-05
# Epoch 5/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9576 - auc: 0.9932 - loss: 0.1051 - precision: 0.9856 - recall: 0.9565
# Epoch 5: val_auc improved from 0.99387 to 0.99394, saving model to best_densenet121_phase2.keras
#
# Epoch 5: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1092s 8s/step - accuracy: 0.9576 - auc: 0.9932 - loss: 0.1051 - precision: 0.9856 - recall: 0.9565 - val_accuracy: 0.9463 - val_auc: 0.9939 - val_loss: 0.1431 - val_precision: 0.9946 - val_recall: 0.9345 - learning_rate: 3.0000e-06
# Epoch 6/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 70s/step - accuracy: 0.9552 - auc: 0.9923 - loss: 0.1081 - precision: 0.9859 - recall: 0.9529
# Epoch 6: val_auc improved from 0.99394 to 0.99409, saving model to best_densenet121_phase2.keras
#
# Epoch 6: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9179s 70s/step - accuracy: 0.9552 - auc: 0.9923 - loss: 0.1081 - precision: 0.9859 - recall: 0.9529 - val_accuracy: 0.9434 - val_auc: 0.9941 - val_loss: 0.1480 - val_precision: 0.9946 - val_recall: 0.9307 - learning_rate: 3.0000e-06
# Epoch 7/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9585 - auc: 0.9941 - loss: 0.0953 - precision: 0.9882 - recall: 0.9552
# Epoch 7: val_auc did not improve from 0.99409
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 650s 5s/step - accuracy: 0.9585 - auc: 0.9941 - loss: 0.0953 - precision: 0.9882 - recall: 0.9552 - val_accuracy: 0.9463 - val_auc: 0.9941 - val_loss: 0.1421 - val_precision: 0.9946 - val_recall: 0.9345 - learning_rate: 3.0000e-06
# Epoch 8/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9612 - auc: 0.9942 - loss: 0.0960 - precision: 0.9916 - recall: 0.9555
# Epoch 8: val_auc improved from 0.99409 to 0.99423, saving model to best_densenet121_phase2.keras
#
# Epoch 8: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 761s 5s/step - accuracy: 0.9612 - auc: 0.9942 - loss: 0.0960 - precision: 0.9916 - recall: 0.9555 - val_accuracy: 0.9473 - val_auc: 0.9942 - val_loss: 0.1389 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 3.0000e-06
# Epoch 9/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9595 - auc: 0.9938 - loss: 0.0975 - precision: 0.9873 - recall: 0.9575
# Epoch 9: val_auc improved from 0.99423 to 0.99427, saving model to best_densenet121_phase2.keras
#
# Epoch 9: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 684s 5s/step - accuracy: 0.9595 - auc: 0.9938 - loss: 0.0975 - precision: 0.9873 - recall: 0.9575 - val_accuracy: 0.9511 - val_auc: 0.9943 - val_loss: 0.1340 - val_precision: 0.9947 - val_recall: 0.9408 - learning_rate: 3.0000e-06
# Epoch 10/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9595 - auc: 0.9941 - loss: 0.0984 - precision: 0.9853 - recall: 0.9594
# Epoch 10: val_auc improved from 0.99427 to 0.99432, saving model to best_densenet121_phase2.keras
#
# Epoch 10: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 872s 6s/step - accuracy: 0.9595 - auc: 0.9941 - loss: 0.0984 - precision: 0.9853 - recall: 0.9594 - val_accuracy: 0.9501 - val_auc: 0.9943 - val_loss: 0.1354 - val_precision: 0.9947 - val_recall: 0.9395 - learning_rate: 3.0000e-06
# Epoch 11/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9600 - auc: 0.9933 - loss: 0.1003 - precision: 0.9876 - recall: 0.9578
# Epoch 11: val_auc did not improve from 0.99432
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 619s 5s/step - accuracy: 0.9600 - auc: 0.9933 - loss: 0.1003 - precision: 0.9876 - recall: 0.9578 - val_accuracy: 0.9473 - val_auc: 0.9943 - val_loss: 0.1372 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 3.0000e-06
# Epoch 12/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9595 - auc: 0.9939 - loss: 0.0973 - precision: 0.9886 - recall: 0.9562
# Epoch 12: val_auc improved from 0.99432 to 0.99450, saving model to best_densenet121_phase2.keras
#
# Epoch 12: finished saving model to best_densenet121_phase2.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 584s 4s/step - accuracy: 0.9595 - auc: 0.9939 - loss: 0.0973 - precision: 0.9886 - recall: 0.9562 - val_accuracy: 0.9463 - val_auc: 0.9945 - val_loss: 0.1393 - val_precision: 0.9960 - val_recall: 0.9332 - learning_rate: 3.0000e-06
# Epoch 13/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 593s/step - accuracy: 0.9605 - auc: 0.9945 - loss: 0.0934 - precision: 0.9889 - recall: 0.9572
# Epoch 13: val_auc improved from 0.99450 to 0.99454, saving model to best_densenet121_phase2.keras
#
# Epoch 13: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 77240s 594s/step - accuracy: 0.9605 - auc: 0.9945 - loss: 0.0934 - precision: 0.9889 - recall: 0.9572 - val_accuracy: 0.9482 - val_auc: 0.9945 - val_loss: 0.1351 - val_precision: 0.9960 - val_recall: 0.9358 - learning_rate: 9.0000e-07
# Epoch 14/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9595 - auc: 0.9949 - loss: 0.0901 - precision: 0.9906 - recall: 0.9542
# Epoch 14: val_auc improved from 0.99454 to 0.99455, saving model to best_densenet121_phase2.keras
#
# Epoch 14: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 627s 5s/step - accuracy: 0.9595 - auc: 0.9949 - loss: 0.0901 - precision: 0.9906 - recall: 0.9542 - val_accuracy: 0.9492 - val_auc: 0.9946 - val_loss: 0.1323 - val_precision: 0.9947 - val_recall: 0.9383 - learning_rate: 9.0000e-07
# Epoch 15/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9657 - auc: 0.9937 - loss: 0.0961 - precision: 0.9884 - recall: 0.9649
# Epoch 15: val_auc did not improve from 0.99455
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 474s 3s/step - accuracy: 0.9657 - auc: 0.9937 - loss: 0.0961 - precision: 0.9884 - recall: 0.9649 - val_accuracy: 0.9473 - val_auc: 0.9945 - val_loss: 0.1360 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 9.0000e-07
# Epoch 16/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9602 - auc: 0.9938 - loss: 0.0985 - precision: 0.9899 - recall: 0.9559
# Epoch 16: val_auc improved from 0.99455 to 0.99461, saving model to best_densenet121_phase2.keras
#
# Epoch 16: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 677s 5s/step - accuracy: 0.9602 - auc: 0.9938 - loss: 0.0985 - precision: 0.9899 - recall: 0.9559 - val_accuracy: 0.9482 - val_auc: 0.9946 - val_loss: 0.1336 - val_precision: 0.9947 - val_recall: 0.9370 - learning_rate: 9.0000e-07
# Epoch 17/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9629 - auc: 0.9941 - loss: 0.0934 - precision: 0.9877 - recall: 0.9617
# Epoch 17: val_auc did not improve from 0.99461
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.6999999249710525e-07.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 528s 4s/step - accuracy: 0.9629 - auc: 0.9941 - loss: 0.0934 - precision: 0.9877 - recall: 0.9617 - val_accuracy: 0.9473 - val_auc: 0.9946 - val_loss: 0.1354 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 9.0000e-07
# Epoch 18/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9621 - auc: 0.9936 - loss: 0.0974 - precision: 0.9893 - recall: 0.9591
# Epoch 18: val_auc improved from 0.99461 to 0.99461, saving model to best_densenet121_phase2.keras
#
# Epoch 18: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 503s 4s/step - accuracy: 0.9621 - auc: 0.9936 - loss: 0.0974 - precision: 0.9893 - recall: 0.9591 - val_accuracy: 0.9473 - val_auc: 0.9946 - val_loss: 0.1351 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 2.7000e-07
# Epoch 19/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9621 - auc: 0.9943 - loss: 0.0901 - precision: 0.9899 - recall: 0.9585
# Epoch 19: val_auc did not improve from 0.99461
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 534s 4s/step - accuracy: 0.9621 - auc: 0.9943 - loss: 0.0901 - precision: 0.9899 - recall: 0.9585 - val_accuracy: 0.9492 - val_auc: 0.9946 - val_loss: 0.1318 - val_precision: 0.9947 - val_recall: 0.9383 - learning_rate: 2.7000e-07
# Epoch 20/20
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9602 - auc: 0.9943 - loss: 0.0958 - precision: 0.9896 - recall: 0.9562
# Epoch 20: val_auc improved from 0.99461 to 0.99465, saving model to best_densenet121_phase2.keras
#
# Epoch 20: finished saving model to best_densenet121_phase2.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 0.9602 - auc: 0.9943 - loss: 0.0958 - precision: 0.9896 - recall: 0.9562 - val_accuracy: 0.9473 - val_auc: 0.9947 - val_loss: 0.1340 - val_precision: 0.9946 - val_recall: 0.9358 - learning_rate: 2.7000e-07
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 11. Évaluation sur le test set

# %%
print("========== EVALUATION FINALE ==========")
test_results = model.evaluate(normalized_test, return_dict=True)
print(test_results)
# Out:
# ========== EVALUATION FINALE ==========
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8958 - auc: 0.9651 - loss: 0.2719 - precision: 0.8842 - recall: 0.9590
# {'accuracy': 0.8958333134651184, 'auc': 0.9651051163673401, 'loss': 0.2718806266784668, 'precision': 0.8841607570648193, 'recall': 0.9589743614196777}

# %% [markdown]
# ## 12. Recherche du seuil optimal
#
# > Le seuil par défaut (0.5) n'est pas optimal quand les classes sont déséquilibrées.
# > On cherche le seuil qui maximise le F1-score de la classe NORMAL (souvent mal classifiée).

# %%
y_true = np.concatenate([y.numpy() for x, y in test_dataset])
y_prob = model.predict(normalized_test).ravel()

best_threshold = 0.5
best_f1_normal = 0

print("--- Recherche du seuil optimal ---")
for threshold in np.arange(0.25, 0.76, 0.05):
    y_pred = (y_prob >= threshold).astype(int)
    f1_normal    = f1_score(y_true, y_pred, pos_label=0)
    f1_pneumonia = f1_score(y_true, y_pred, pos_label=1)
    print(f"Seuil {threshold:.2f} | F1 NORMAL={f1_normal:.3f} | F1 PNEUMONIA={f1_pneumonia:.3f}")
    if f1_normal > best_f1_normal:
        best_f1_normal = f1_normal
        best_threshold = threshold

print(f"\n✅ Meilleur seuil : {best_threshold:.2f}")

y_pred_final = (y_prob >= best_threshold).astype(int)
print("\n--- Classification Report Final ---")
print(classification_report(y_true, y_pred_final, target_names=["NORMAL", "PNEUMONIA"]))

cm = confusion_matrix(y_true, y_pred_final)
print("Matrice de confusion :")
print(cm)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step
# --- Recherche du seuil optimal ---
# Seuil 0.25 | F1 NORMAL=0.761 | F1 PNEUMONIA=0.892
# Seuil 0.30 | F1 NORMAL=0.786 | F1 PNEUMONIA=0.900
# Seuil 0.35 | F1 NORMAL=0.816 | F1 PNEUMONIA=0.911
# Seuil 0.40 | F1 NORMAL=0.838 | F1 PNEUMONIA=0.918
# Seuil 0.45 | F1 NORMAL=0.844 | F1 PNEUMONIA=0.918
# Seuil 0.50 | F1 NORMAL=0.851 | F1 PNEUMONIA=0.920
# Seuil 0.55 | F1 NORMAL=0.858 | F1 PNEUMONIA=0.922
# Seuil 0.60 | F1 NORMAL=0.862 | F1 PNEUMONIA=0.922
# Seuil 0.65 | F1 NORMAL=0.873 | F1 PNEUMONIA=0.927
# Seuil 0.70 | F1 NORMAL=0.883 | F1 PNEUMONIA=0.931
# Seuil 0.75 | F1 NORMAL=0.885 | F1 PNEUMONIA=0.931
#
# ✅ Meilleur seuil : 0.75
#
# --- Classification Report Final ---
#               precision    recall  f1-score   support
#
#       NORMAL       0.88      0.88      0.88       234
#    PNEUMONIA       0.93      0.93      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.91      0.91      0.91       624
# weighted avg       0.91      0.91      0.91       624
#
# Matrice de confusion :
# [[207  27]
#  [ 27 363]]

# %% [markdown]
# ## 13. Courbes d'apprentissage (Phase 1 + Phase 2)

# %%
def plot_history(h1, h2):
    metrics = ["accuracy", "loss", "auc", "recall"]
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    axes = axes.ravel()
    offset = len(h1.history["loss"])

    for i, metric in enumerate(metrics):
        axes[i].plot(h1.history[metric], label="train phase1", color="steelblue")
        axes[i].plot(h1.history[f"val_{metric}"], label="val phase1",
                     color="steelblue", linestyle="--")
        ep2 = range(offset, offset + len(h2.history[metric]))
        axes[i].plot(ep2, h2.history[metric], label="train phase2", color="darkorange")
        axes[i].plot(ep2, h2.history[f"val_{metric}"], label="val phase2",
                     color="darkorange", linestyle="--")
        axes[i].axvline(x=offset, color="gray", linestyle=":", label="début fine-tuning")
        axes[i].set_title(metric.upper(), fontsize=12)
        axes[i].legend(fontsize=8)
        axes[i].grid(True, alpha=0.4)

    plt.suptitle("Courbes d'apprentissage — DenseNet121 Amélioré", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.savefig("courbes_apprentissage.png", dpi=150, bbox_inches="tight")
    plt.show()
    print("Graphique sauvegardé : courbes_apprentissage.png")

plot_history(history1, history2)
# Out:
# Graphique sauvegardé : courbes_apprentissage.png

# %%
print("Dossier de travail actuel :")
print(os.getcwd())
# Out:
# Dossier de travail actuel :
# c:\Users\HP\Downloads

# %%
# Afficher les couches du modèle
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.__class__.__name__)
# Out:
# 0 input_layer_2 InputLayer
# 1 densenet121 Functional
# 2 global_average_pooling2d GlobalAveragePooling2D
# 3 batch_normalization BatchNormalization
# 4 dense Dense
# 5 dropout Dropout
# 6 dense_1 Dense

# %%
densenet = model.get_layer("densenet121")

for i, layer in enumerate(densenet.layers):
    print(i, layer.name, layer.__class__.__name__)
# Out:
# 0 input_layer_1 InputLayer
# 1 zero_padding2d ZeroPadding2D
# 2 conv1_conv Conv2D
# 3 conv1_bn BatchNormalization
# 4 conv1_relu Activation
# 5 zero_padding2d_1 ZeroPadding2D
# 6 pool1 MaxPooling2D
# 7 conv2_block1_0_bn BatchNormalization
# 8 conv2_block1_0_relu Activation
# 9 conv2_block1_1_conv Conv2D
# 10 conv2_block1_1_bn BatchNormalization
# 11 conv2_block1_1_relu Activation
# 12 conv2_block1_2_conv Conv2D
# 13 conv2_block1_concat Concatenate
# 14 conv2_block2_0_bn BatchNormalization
# 15 conv2_block2_0_relu Activation
# 16 conv2_block2_1_conv Conv2D
# 17 conv2_block2_1_bn BatchNormalization
# 18 conv2_block2_1_relu Activation
# 19 conv2_block2_2_conv Conv2D
# 20 conv2_block2_concat Concatenate
# 21 conv2_block3_0_bn BatchNormalization
# 22 conv2_block3_0_relu Activation
# 23 conv2_block3_1_conv Conv2D
# 24 conv2_block3_1_bn BatchNormalization
# 25 conv2_block3_1_relu Activation
# 26 conv2_block3_2_conv Conv2D
# 27 conv2_block3_concat Concatenate
# 28 conv2_block4_0_bn BatchNormalization
# 29 conv2_block4_0_relu Activation
# 30 conv2_block4_1_conv Conv2D
# 31 conv2_block4_1_bn BatchNormalization
# 32 conv2_block4_1_relu Activation
# 33 conv2_block4_2_conv Conv2D
# 34 conv2_block4_concat Concatenate
# 35 conv2_block5_0_bn BatchNormalization
# 36 conv2_block5_0_relu Activation
# 37 conv2_block5_1_conv Conv2D
# 38 conv2_block5_1_bn BatchNormalization
# 39 conv2_block5_1_relu Activation
# 40 conv2_block5_2_conv Conv2D
# 41 conv2_block5_concat Concatenate
# 42 conv2_block6_0_bn BatchNormalization
# 43 conv2_block6_0_relu Activation
# 44 conv2_block6_1_conv Conv2D
# 45 conv2_block6_1_bn BatchNormalization
# 46 conv2_block6_1_relu Activation
# 47 conv2_block6_2_conv Conv2D
# 48 conv2_block6_concat Concatenate
# 49 pool2_bn BatchNormalization
# 50 pool2_relu Activation
# 51 pool2_conv Conv2D
# 52 pool2_pool AveragePooling2D
# 53 conv3_block1_0_bn BatchNormalization
# 54 conv3_block1_0_relu Activation
# 55 conv3_block1_1_conv Conv2D
# 56 conv3_block1_1_bn BatchNormalization
# 57 conv3_block1_1_relu Activation
# 58 conv3_block1_2_conv Conv2D
# 59 conv3_block1_concat Concatenate
# 60 conv3_block2_0_bn BatchNormalization
# 61 conv3_block2_0_relu Activation
# 62 conv3_block2_1_conv Conv2D
# 63 conv3_block2_1_bn BatchNormalization
# 64 conv3_block2_1_relu Activation
# 65 conv3_block2_2_conv Conv2D
# 66 conv3_block2_concat Concatenate
# 67 conv3_block3_0_bn BatchNormalization
# 68 conv3_block3_0_relu Activation
# 69 conv3_block3_1_conv Conv2D
# 70 conv3_block3_1_bn BatchNormalization
# 71 conv3_block3_1_relu Activation
# 72 conv3_block3_2_conv Conv2D
# 73 conv3_block3_concat Concatenate
# 74 conv3_block4_0_bn BatchNormalization
# 75 conv3_block4_0_relu Activation
# 76 conv3_block4_1_conv Conv2D
# 77 conv3_block4_1_bn BatchNormalization
# 78 conv3_block4_1_relu Activation
# 79 conv3_block4_2_conv Conv2D
# 80 conv3_block4_concat Concatenate
# 81 conv3_block5_0_bn BatchNormalization
# 82 conv3_block5_0_relu Activation
# 83 conv3_block5_1_conv Conv2D
# 84 conv3_block5_1_bn BatchNormalization
# 85 conv3_block5_1_relu Activation
# 86 conv3_block5_2_conv Conv2D
# 87 conv3_block5_concat Concatenate
# 88 conv3_block6_0_bn BatchNormalization
# 89 conv3_block6_0_relu Activation
# 90 conv3_block6_1_conv Conv2D
# 91 conv3_block6_1_bn BatchNormalization
# 92 conv3_block6_1_relu Activation
# 93 conv3_block6_2_conv Conv2D
# 94 conv3_block6_concat Concatenate
# 95 conv3_block7_0_bn BatchNormalization
# 96 conv3_block7_0_relu Activation
# 97 conv3_block7_1_conv Conv2D
# 98 conv3_block7_1_bn BatchNormalization
# 99 conv3_block7_1_relu Activation
# 100 conv3_block7_2_conv Conv2D
# 101 conv3_block7_concat Concatenate
# 102 conv3_block8_0_bn BatchNormalization
# 103 conv3_block8_0_relu Activation
# 104 conv3_block8_1_conv Conv2D
# 105 conv3_block8_1_bn BatchNormalization
# 106 conv3_block8_1_relu Activation
# 107 conv3_block8_2_conv Conv2D
# 108 conv3_block8_concat Concatenate
# 109 conv3_block9_0_bn BatchNormalization
# 110 conv3_block9_0_relu Activation
# 111 conv3_block9_1_conv Conv2D
# 112 conv3_block9_1_bn BatchNormalization
# 113 conv3_block9_1_relu Activation
# 114 conv3_block9_2_conv Conv2D
# 115 conv3_block9_concat Concatenate
# 116 conv3_block10_0_bn BatchNormalization
# 117 conv3_block10_0_relu Activation
# 118 conv3_block10_1_conv Conv2D
# 119 conv3_block10_1_bn BatchNormalization
# 120 conv3_block10_1_relu Activation
# 121 conv3_block10_2_conv Conv2D
# 122 conv3_block10_concat Concatenate
# 123 conv3_block11_0_bn BatchNormalization
# 124 conv3_block11_0_relu Activation
# 125 conv3_block11_1_conv Conv2D
# 126 conv3_block11_1_bn BatchNormalization
# 127 conv3_block11_1_relu Activation
# 128 conv3_block11_2_conv Conv2D
# 129 conv3_block11_concat Concatenate
# 130 conv3_block12_0_bn BatchNormalization
# 131 conv3_block12_0_relu Activation
# 132 conv3_block12_1_conv Conv2D
# 133 conv3_block12_1_bn BatchNormalization
# 134 conv3_block12_1_relu Activation
# 135 conv3_block12_2_conv Conv2D
# 136 conv3_block12_concat Concatenate
# 137 pool3_bn BatchNormalization
# 138 pool3_relu Activation
# 139 pool3_conv Conv2D
# 140 pool3_pool AveragePooling2D
# 141 conv4_block1_0_bn BatchNormalization
# 142 conv4_block1_0_relu Activation
# 143 conv4_block1_1_conv Conv2D
# 144 conv4_block1_1_bn BatchNormalization
# 145 conv4_block1_1_relu Activation
# 146 conv4_block1_2_conv Conv2D
# 147 conv4_block1_concat Concatenate
# 148 conv4_block2_0_bn BatchNormalization
# 149 conv4_block2_0_relu Activation
# 150 conv4_block2_1_conv Conv2D
# 151 conv4_block2_1_bn BatchNormalization
# 152 conv4_block2_1_relu Activation
# 153 conv4_block2_2_conv Conv2D
# 154 conv4_block2_concat Concatenate
# 155 conv4_block3_0_bn BatchNormalization
# 156 conv4_block3_0_relu Activation
# 157 conv4_block3_1_conv Conv2D
# 158 conv4_block3_1_bn BatchNormalization
# 159 conv4_block3_1_relu Activation
# 160 conv4_block3_2_conv Conv2D
# 161 conv4_block3_concat Concatenate
# 162 conv4_block4_0_bn BatchNormalization
# 163 conv4_block4_0_relu Activation
# 164 conv4_block4_1_conv Conv2D
# 165 conv4_block4_1_bn BatchNormalization
# 166 conv4_block4_1_relu Activation
# 167 conv4_block4_2_conv Conv2D
# 168 conv4_block4_concat Concatenate
# 169 conv4_block5_0_bn BatchNormalization
# 170 conv4_block5_0_relu Activation
# 171 conv4_block5_1_conv Conv2D
# 172 conv4_block5_1_bn BatchNormalization
# 173 conv4_block5_1_relu Activation
# 174 conv4_block5_2_conv Conv2D
# 175 conv4_block5_concat Concatenate
# 176 conv4_block6_0_bn BatchNormalization
# 177 conv4_block6_0_relu Activation
# 178 conv4_block6_1_conv Conv2D
# 179 conv4_block6_1_bn BatchNormalization
# 180 conv4_block6_1_relu Activation
# 181 conv4_block6_2_conv Conv2D
# 182 conv4_block6_concat Concatenate
# 183 conv4_block7_0_bn BatchNormalization
# 184 conv4_block7_0_relu Activation
# 185 conv4_block7_1_conv Conv2D
# 186 conv4_block7_1_bn BatchNormalization
# 187 conv4_block7_1_relu Activation
# 188 conv4_block7_2_conv Conv2D
# 189 conv4_block7_concat Concatenate
# 190 conv4_block8_0_bn BatchNormalization
# 191 conv4_block8_0_relu Activation
# 192 conv4_block8_1_conv Conv2D
# 193 conv4_block8_1_bn BatchNormalization
# 194 conv4_block8_1_relu Activation
# 195 conv4_block8_2_conv Conv2D
# 196 conv4_block8_concat Concatenate
# 197 conv4_block9_0_bn BatchNormalization
# 198 conv4_block9_0_relu Activation
# 199 conv4_block9_1_conv Conv2D
# 200 conv4_block9_1_bn BatchNormalization
# 201 conv4_block9_1_relu Activation
# 202 conv4_block9_2_conv Conv2D
# 203 conv4_block9_concat Concatenate
# 204 conv4_block10_0_bn BatchNormalization
# 205 conv4_block10_0_relu Activation
# 206 conv4_block10_1_conv Conv2D
# 207 conv4_block10_1_bn BatchNormalization
# 208 conv4_block10_1_relu Activation
# 209 conv4_block10_2_conv Conv2D
# 210 conv4_block10_concat Concatenate
# 211 conv4_block11_0_bn BatchNormalization
# 212 conv4_block11_0_relu Activation
# 213 conv4_block11_1_conv Conv2D
# 214 conv4_block11_1_bn BatchNormalization
# 215 conv4_block11_1_relu Activation
# 216 conv4_block11_2_conv Conv2D
# 217 conv4_block11_concat Concatenate
# 218 conv4_block12_0_bn BatchNormalization
# 219 conv4_block12_0_relu Activation
# 220 conv4_block12_1_conv Conv2D
# 221 conv4_block12_1_bn BatchNormalization
# 222 conv4_block12_1_relu Activation
# 223 conv4_block12_2_conv Conv2D
# 224 conv4_block12_concat Concatenate
# 225 conv4_block13_0_bn BatchNormalization
# 226 conv4_block13_0_relu Activation
# 227 conv4_block13_1_conv Conv2D
# 228 conv4_block13_1_bn BatchNormalization
# 229 conv4_block13_1_relu Activation
# 230 conv4_block13_2_conv Conv2D
# 231 conv4_block13_concat Concatenate
# 232 conv4_block14_0_bn BatchNormalization
# 233 conv4_block14_0_relu Activation
# 234 conv4_block14_1_conv Conv2D
# 235 conv4_block14_1_bn BatchNormalization
# 236 conv4_block14_1_relu Activation
# 237 conv4_block14_2_conv Conv2D
# 238 conv4_block14_concat Concatenate
# 239 conv4_block15_0_bn BatchNormalization
# 240 conv4_block15_0_relu Activation
# 241 conv4_block15_1_conv Conv2D
# 242 conv4_block15_1_bn BatchNormalization
# 243 conv4_block15_1_relu Activation
# 244 conv4_block15_2_conv Conv2D
# 245 conv4_block15_concat Concatenate
# 246 conv4_block16_0_bn BatchNormalization
# 247 conv4_block16_0_relu Activation
# 248 conv4_block16_1_conv Conv2D
# 249 conv4_block16_1_bn BatchNormalization
# 250 conv4_block16_1_relu Activation
# 251 conv4_block16_2_conv Conv2D
# 252 conv4_block16_concat Concatenate
# 253 conv4_block17_0_bn BatchNormalization
# 254 conv4_block17_0_relu Activation
# 255 conv4_block17_1_conv Conv2D
# 256 conv4_block17_1_bn BatchNormalization
# 257 conv4_block17_1_relu Activation
# 258 conv4_block17_2_conv Conv2D
# 259 conv4_block17_concat Concatenate
# 260 conv4_block18_0_bn BatchNormalization
# 261 conv4_block18_0_relu Activation
# 262 conv4_block18_1_conv Conv2D
# 263 conv4_block18_1_bn BatchNormalization
# 264 conv4_block18_1_relu Activation
# 265 conv4_block18_2_conv Conv2D
# 266 conv4_block18_concat Concatenate
# 267 conv4_block19_0_bn BatchNormalization
# 268 conv4_block19_0_relu Activation
# 269 conv4_block19_1_conv Conv2D
# 270 conv4_block19_1_bn BatchNormalization
# 271 conv4_block19_1_relu Activation
# 272 conv4_block19_2_conv Conv2D
# 273 conv4_block19_concat Concatenate
# 274 conv4_block20_0_bn BatchNormalization
# 275 conv4_block20_0_relu Activation
# 276 conv4_block20_1_conv Conv2D
# 277 conv4_block20_1_bn BatchNormalization
# 278 conv4_block20_1_relu Activation
# 279 conv4_block20_2_conv Conv2D
# 280 conv4_block20_concat Concatenate
# 281 conv4_block21_0_bn BatchNormalization
# 282 conv4_block21_0_relu Activation
# 283 conv4_block21_1_conv Conv2D
# 284 conv4_block21_1_bn BatchNormalization
# 285 conv4_block21_1_relu Activation
# 286 conv4_block21_2_conv Conv2D
# 287 conv4_block21_concat Concatenate
# 288 conv4_block22_0_bn BatchNormalization
# 289 conv4_block22_0_relu Activation
# 290 conv4_block22_1_conv Conv2D
# 291 conv4_block22_1_bn BatchNormalization
# 292 conv4_block22_1_relu Activation
# 293 conv4_block22_2_conv Conv2D
# 294 conv4_block22_concat Concatenate
# 295 conv4_block23_0_bn BatchNormalization
# 296 conv4_block23_0_relu Activation
# 297 conv4_block23_1_conv Conv2D
# 298 conv4_block23_1_bn BatchNormalization
# 299 conv4_block23_1_relu Activation
# 300 conv4_block23_2_conv Conv2D
# 301 conv4_block23_concat Concatenate
# 302 conv4_block24_0_bn BatchNormalization
# 303 conv4_block24_0_relu Activation
# 304 conv4_block24_1_conv Conv2D
# 305 conv4_block24_1_bn BatchNormalization
# 306 conv4_block24_1_relu Activation
# 307 conv4_block24_2_conv Conv2D
# 308 conv4_block24_concat Concatenate
# 309 pool4_bn BatchNormalization
# 310 pool4_relu Activation
# 311 pool4_conv Conv2D
# 312 pool4_pool AveragePooling2D
# 313 conv5_block1_0_bn BatchNormalization
# 314 conv5_block1_0_relu Activation
# 315 conv5_block1_1_conv Conv2D
# 316 conv5_block1_1_bn BatchNormalization
# 317 conv5_block1_1_relu Activation
# 318 conv5_block1_2_conv Conv2D
# 319 conv5_block1_concat Concatenate
# 320 conv5_block2_0_bn BatchNormalization
# 321 conv5_block2_0_relu Activation
# 322 conv5_block2_1_conv Conv2D
# 323 conv5_block2_1_bn BatchNormalization
# 324 conv5_block2_1_relu Activation
# 325 conv5_block2_2_conv Conv2D
# 326 conv5_block2_concat Concatenate
# 327 conv5_block3_0_bn BatchNormalization
# 328 conv5_block3_0_relu Activation
# 329 conv5_block3_1_conv Conv2D
# 330 conv5_block3_1_bn BatchNormalization
# 331 conv5_block3_1_relu Activation
# 332 conv5_block3_2_conv Conv2D
# 333 conv5_block3_concat Concatenate
# 334 conv5_block4_0_bn BatchNormalization
# 335 conv5_block4_0_relu Activation
# 336 conv5_block4_1_conv Conv2D
# 337 conv5_block4_1_bn BatchNormalization
# 338 conv5_block4_1_relu Activation
# 339 conv5_block4_2_conv Conv2D
# 340 conv5_block4_concat Concatenate
# 341 conv5_block5_0_bn BatchNormalization
# 342 conv5_block5_0_relu Activation
# 343 conv5_block5_1_conv Conv2D
# 344 conv5_block5_1_bn BatchNormalization
# 345 conv5_block5_1_relu Activation
# 346 conv5_block5_2_conv Conv2D
# 347 conv5_block5_concat Concatenate
# 348 conv5_block6_0_bn BatchNormalization
# 349 conv5_block6_0_relu Activation
# 350 conv5_block6_1_conv Conv2D
# 351 conv5_block6_1_bn BatchNormalization
# 352 conv5_block6_1_relu Activation
# 353 conv5_block6_2_conv Conv2D
# 354 conv5_block6_concat Concatenate
# 355 conv5_block7_0_bn BatchNormalization
# 356 conv5_block7_0_relu Activation
# 357 conv5_block7_1_conv Conv2D
# 358 conv5_block7_1_bn BatchNormalization
# 359 conv5_block7_1_relu Activation
# 360 conv5_block7_2_conv Conv2D
# 361 conv5_block7_concat Concatenate
# 362 conv5_block8_0_bn BatchNormalization
# 363 conv5_block8_0_relu Activation
# 364 conv5_block8_1_conv Conv2D
# 365 conv5_block8_1_bn BatchNormalization
# 366 conv5_block8_1_relu Activation
# 367 conv5_block8_2_conv Conv2D
# 368 conv5_block8_concat Concatenate
# 369 conv5_block9_0_bn BatchNormalization
# 370 conv5_block9_0_relu Activation
# 371 conv5_block9_1_conv Conv2D
# 372 conv5_block9_1_bn BatchNormalization
# 373 conv5_block9_1_relu Activation
# 374 conv5_block9_2_conv Conv2D
# 375 conv5_block9_concat Concatenate
# 376 conv5_block10_0_bn BatchNormalization
# 377 conv5_block10_0_relu Activation
# 378 conv5_block10_1_conv Conv2D
# 379 conv5_block10_1_bn BatchNormalization
# 380 conv5_block10_1_relu Activation
# 381 conv5_block10_2_conv Conv2D
# 382 conv5_block10_concat Concatenate
# 383 conv5_block11_0_bn BatchNormalization
# 384 conv5_block11_0_relu Activation
# 385 conv5_block11_1_conv Conv2D
# 386 conv5_block11_1_bn BatchNormalization
# 387 conv5_block11_1_relu Activation
# 388 conv5_block11_2_conv Conv2D
# 389 conv5_block11_concat Concatenate
# 390 conv5_block12_0_bn BatchNormalization
# 391 conv5_block12_0_relu Activation
# 392 conv5_block12_1_conv Conv2D
# 393 conv5_block12_1_bn BatchNormalization
# 394 conv5_block12_1_relu Activation
# 395 conv5_block12_2_conv Conv2D
# 396 conv5_block12_concat Concatenate
# 397 conv5_block13_0_bn BatchNormalization
# 398 conv5_block13_0_relu Activation
# 399 conv5_block13_1_conv Conv2D
# 400 conv5_block13_1_bn BatchNormalization
# 401 conv5_block13_1_relu Activation
# 402 conv5_block13_2_conv Conv2D
# 403 conv5_block13_concat Concatenate
# 404 conv5_block14_0_bn BatchNormalization
# 405 conv5_block14_0_relu Activation
# 406 conv5_block14_1_conv Conv2D
# 407 conv5_block14_1_bn BatchNormalization
# 408 conv5_block14_1_relu Activation
# 409 conv5_block14_2_conv Conv2D
# 410 conv5_block14_concat Concatenate
# 411 conv5_block15_0_bn BatchNormalization
# 412 conv5_block15_0_relu Activation
# 413 conv5_block15_1_conv Conv2D
# 414 conv5_block15_1_bn BatchNormalization
# 415 conv5_block15_1_relu Activation
# 416 conv5_block15_2_conv Conv2D
# 417 conv5_block15_concat Concatenate
# 418 conv5_block16_0_bn BatchNormalization
# 419 conv5_block16_0_relu Activation
# 420 conv5_block16_1_conv Conv2D
# 421 conv5_block16_1_bn BatchNormalization
# 422 conv5_block16_1_relu Activation
# 423 conv5_block16_2_conv Conv2D
# 424 conv5_block16_concat Concatenate
# 425 bn BatchNormalization
# 426 relu Activation

# %%
densenet = model.get_layer("densenet121")

target_layer = densenet.get_layer("relu")

print("Nom :", target_layer.name)
print("Type :", target_layer.__class__.__name__)
print("Output shape :", target_layer.output.shape)
# Out:
# Nom : relu
# Type : Activation
# Output shape : (None, 7, 7, 1024)

# %%
densenet = model.get_layer("densenet121")

print("=== DENSENET ===")
print("Input :", densenet.input)
print("Input shape :", densenet.input_shape)

print("Output :", densenet.output)
print("Output shape :", densenet.output_shape)

print("\n=== MODEL PRINCIPAL ===")
print("Input :", model.input)
print("Input shape :", model.input_shape)

print("Output :", model.output)
print("Output shape :", model.output_shape)
# Out:
# === DENSENET ===
# Input : <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_6>
# Input shape : (None, 224, 224, 3)
# Output : <KerasTensor shape=(None, 7, 7, 1024), dtype=float32, sparse=False, ragged=False, name=keras_tensor_432>
# Output shape : (None, 7, 7, 1024)
#
# === MODEL PRINCIPAL ===
# Input : <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_433>
# Input shape : (None, 224, 224, 3)
# Output : <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_439>
# Output shape : (None, 1)

# %%
densenet = model.get_layer("densenet121")

gap = model.get_layer("global_average_pooling2d")

print("DenseNet output:")
print(densenet.output)

print("\nGAP input:")
print(gap.input)

print("\nMême tenseur ?")
print(densenet.output is gap.input)
# Out:
# DenseNet output:
# <KerasTensor shape=(None, 7, 7, 1024), dtype=float32, sparse=False, ragged=False, name=keras_tensor_432>
#
# GAP input:
# <KerasTensor shape=(None, 7, 7, 1024), dtype=float32, sparse=False, ragged=False, name=keras_tensor_434>
#
# Même tenseur ?
# False

# %%
densenet = model.get_layer("densenet121")

gap = model.get_layer("global_average_pooling2d")
bn = model.get_layer("batch_normalization")
dense = model.get_layer("dense")
dropout = model.get_layer("dropout")
dense_1 = model.get_layer("dense_1")

# %%
# ============================================================
# 1 — CONSTRUCTION DU MODÈLE GRAD-CAM
# ============================================================

import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.applications.densenet import preprocess_input

# Features convolutionnelles 7 x 7 x 1024 connectées au modèle principal
last_conv_output = model.get_layer(
    "global_average_pooling2d"
).input

grad_model = tf.keras.models.Model(
    inputs=model.inputs,
    outputs=[
        last_conv_output,
        model.output
    ]
)

print("Grad-CAM prêt")
print("Features :", last_conv_output.shape)
print("Sortie modèle :", model.output.shape)
# Out:
# Grad-CAM prêt
# Features : (None, 7, 7, 1024)
# Sortie modèle : (None, 1)

# %%
# ============================================================
# 2 — GRAD-CAM AUTOMATIQUE + SAUVEGARDE
# ============================================================

def gradcam_auto(
    image_path,
    model,
    grad_model,
    threshold=0.75,
    output_dir="gradcam_results"
):

    # 1. Chargement et preprocessing
    image = Image.open(image_path).convert("RGB")
    image_resized = image.resize((224, 224))

    image_array = np.array(
        image_resized,
        dtype=np.float32
    )

    image_array = np.expand_dims(
        image_array,
        axis=0
    )

    image_preprocessed = preprocess_input(
        image_array
    )

    # 2. Prédiction + gradients
    with tf.GradientTape() as tape:

        conv_outputs, predictions = grad_model(
            image_preprocessed
        )

        pneumonia_probability = predictions[:, 0]

        if float(pneumonia_probability[0]) >= threshold:
            predicted_class = "PNEUMONIA"
            class_score = pneumonia_probability
        else:
            predicted_class = "NORMAL"
            class_score = 1.0 - pneumonia_probability

    grads = tape.gradient(
        class_score,
        conv_outputs
    )

    pooled_grads = tf.reduce_mean(
        grads,
        axis=(0, 1, 2)
    )

    conv_outputs = conv_outputs[0]

    heatmap = tf.reduce_sum(
        conv_outputs * pooled_grads,
        axis=-1
    )

    heatmap = tf.maximum(
        heatmap,
        0
    )

    max_value = tf.reduce_max(heatmap)

    if max_value > 0:
        heatmap = heatmap / max_value

    heatmap = heatmap.numpy()

    pneumonia_probability = float(
        pneumonia_probability[0]
    )

    if predicted_class == "PNEUMONIA":
        class_probability = pneumonia_probability
    else:
        class_probability = 1.0 - pneumonia_probability

    # 3. Affichage
    fig, ax = plt.subplots(figsize=(7, 7))

    ax.imshow(image)

    ax.imshow(
        heatmap,
        cmap="jet",
        alpha=0.40,
        extent=(0, image.width, image.height, 0),
        interpolation="bilinear"
    )

    ax.set_title(
        f"Grad-CAM — Classe {predicted_class}\n"
        f"P({predicted_class}) = {class_probability:.6f}"
    )

    ax.axis("off")
    plt.show()

    # 4. Sauvegarde
    os.makedirs(
        output_dir,
        exist_ok=True
    )

    image_name = os.path.splitext(
        os.path.basename(image_path)
    )[0]

    output_path = os.path.join(
        output_dir,
        f"{image_name}_gradcam.png"
    )

    fig_save, ax_save = plt.subplots(figsize=(7, 7))

    ax_save.imshow(image)

    ax_save.imshow(
        heatmap,
        cmap="jet",
        alpha=0.40,
        extent=(0, image.width, image.height, 0),
        interpolation="bilinear"
    )

    ax_save.axis("off")

    fig_save.savefig(
        output_path,
        bbox_inches="tight",
        pad_inches=0,
        dpi=200
    )

    plt.close(fig_save)

    return (
        predicted_class,
        pneumonia_probability,
        heatmap,
        output_path
    )

# %%
# ============================================================
# 3 — TEST SUR UNE IMAGE NORMAL
# ============================================================

image_path = r"C:\Users\HP\Documents\IA\Stage\data\chest_xray\test\NORMAL\IM-0001-0001.jpeg"

predicted_class, probability, heatmap, gradcam_path = gradcam_auto(
    image_path,
    model,
    grad_model,
    threshold=0.75
)

print("Classe :", predicted_class)
print("P(PNEUMONIA) :", probability)
print("Grad-CAM :", gradcam_path)
# Out:
# Classe : NORMAL
# P(PNEUMONIA) : 0.0378575436770916
# Grad-CAM : gradcam_results\IM-0001-0001_gradcam.png

# %%
# ============================================================
# 4 — TEST SUR UNE IMAGE PNEUMONIA
# ============================================================

image_path = r"C:\Users\HP\Documents\IA\Stage\data\chest_xray\test\PNEUMONIA\person1_virus_6.jpeg"

predicted_class, probability, heatmap, gradcam_path = gradcam_auto(
    image_path,
    model,
    grad_model,
    threshold=0.75
)

print("Classe :", predicted_class)
print("P(PNEUMONIA) :", probability)
print("Grad-CAM :", gradcam_path)
# Out:
# Classe : PNEUMONIA
# P(PNEUMONIA) : 0.9997476935386658
# Grad-CAM : gradcam_results\person1_virus_6_gradcam.png
